# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=220629820aa4e64a14880a6d84d41e42&language=en-US&page=1').json()

# %%
popularity =[]
vote_count = []
original_language = []
title = []
vote_average = []
overview = []
release_date = []

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d = {'title':title, 'overview':overview, 'release_date':release_date,
         'original_language': original_language, 'popularity':popularity,
         'release_date':release_date,'vote_count':vote_count, 
         'vote_average':vote_average}
    
df = pd.DataFrame(d)

df.head()
# Out:
#                       title  \
# 0    Thor: Love and Thunder
# 1   Jurassic World Dominion
# 2  Minions: The Rise of Gru
# 3                      Prey
# 4         Top Gun: Maverick
#
#                                             overview release_date  \
# 0  After his retirement is interrupted by Gorr th...   2022-07-06
# 1  Four years after Isla Nublar was destroyed, di...   2022-06-01
# 2  A fanboy of a supervillain supergroup known as...   2022-06-29
# 3  When danger threatens her camp, the fierce and...   2022-08-02
# 4  After more than thirty years of service as one...   2022-05-24
#
#   original_language  popularity  vote_count  vote_average
# 0                en    8625.547        1774           6.8
# 1                en    4799.187        2643           7.1
# 2                en    4511.803        1199           7.8
# 3                en    4477.547        1711           8.2
# 4                en    4227.421        1859           8.3

# %% [markdown]
# ### Now we need to do this for every page and append it.

# %%
final = pd.DataFrame()
for j in range(1, 31):
    res = requests.get(f'https://api.themoviedb.org/3/movie/popular?api_key=220629820aa4e64a14880a6d84d41e42&language=en-US&page={j}').text
    response = json.loads(res)
    popularity =[]
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_date = []

    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])

    d = {'title':title, 'overview':overview, 'release_date':release_date,
             'original_language': original_language, 'popularity':popularity,
             'release_date':release_date,'vote_count':vote_count, 
             'vote_average':vote_average}

    df = pd.DataFrame(d)
    
    final = final.append(df, ignore_index=True) #index wont repeat
final

# %%
final.to_csv('movies.csv')
